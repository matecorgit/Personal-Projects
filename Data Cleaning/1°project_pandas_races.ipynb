# %%
#Import libraries
import pandas as pd
import seaborn as sns

# %%
#Read de data
df = pd.read_csv('TWO_CENTURIES_OF_UM_RACES.csv')
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_8448\2360805225.py:2: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('TWO_CENTURIES_OF_UM_RACES.csv')

# %%
#See the data
df.head()
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance        Athlete club  \
# 0                         22           4:51:39 h               Tnfrc
# 1                         22           5:15:45 h  Roberto Echeverría
# 2                         22           5:16:44 h   Puro Trail Osorno
# 3                         22           5:34:13 h            Columbia
# 4                         22           5:54:14 h      Baguales Trail
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# 0             CHI                 1978.0              M                  M35
# 1             CHI                 1981.0              M                  M35
# 2             CHI                 1987.0              M                  M23
# 3             ARG                 1976.0              M                  M40
# 4             CHI                 1992.0              M                  M23
#
#   Athlete average speed  Athlete ID
# 0                10.286           0
# 1                 9.501           1
# 2                 9.472           2
# 3                 8.976           3
# 4                 8.469           4

# %%
#Formato
df.shape
# Out:
# (7117634, 13)

# %%
#Tipos de datos
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
#Clean up data

# %%
#Only want USA Races, 50km or 50miles, 2020

# %%
#50km or 50mi
#Combine 50k/50mi whit isin
df[df['Event distance/length'].isin(['50km','50mi'])].head(6)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
# 5           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance        Athlete club  \
# 0                         22           4:51:39 h               Tnfrc
# 1                         22           5:15:45 h  Roberto Echeverría
# 2                         22           5:16:44 h   Puro Trail Osorno
# 3                         22           5:34:13 h            Columbia
# 4                         22           5:54:14 h      Baguales Trail
# 5                         22           6:25:01 h                 NaN
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# 0             CHI                 1978.0              M                  M35
# 1             CHI                 1981.0              M                  M35
# 2             CHI                 1987.0              M                  M23
# 3             ARG                 1976.0              M                  M40
# 4             CHI                 1992.0              M                  M23
# 5             ARG                 1974.0              M                  M40
#
#   Athlete average speed  Athlete ID
# 0                10.286           0
# 1                 9.501           1
# 2                 9.472           2
# 3                 8.976           3
# 4                 8.469           4
# 5                 7.792           5

# %%
#50km or 50mi + 2020 races
df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event'] == 2020)].head(5)
# Out:
#          Year of event     Event dates  \
# 2538571           2020  07.-09.02.2020
# 2538572           2020  07.-09.02.2020
# 2538573           2020  07.-09.02.2020
# 2538574           2020  07.-09.02.2020
# 2538575           2020  07.-09.02.2020
#
#                                       Event name Event distance/length  \
# 2538571  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538572  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538573  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538574  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538575  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
#
#          Event number of finishers Athlete performance Athlete club  \
# 2538571                         38           7:34:19 h          日本隊
# 2538572                         38           7:43:50 h          NaN
# 2538573                         38           8:04:40 h          NaN
# 2538574                         38           8:30:49 h    台灣大腳ㄚ長跑協會
# 2538575                         38           8:34:47 h          NaN
#
#         Athlete country  Athlete year of birth Athlete gender  \
# 2538571             JPN                 1965.0              M
# 2538572             AUS                 1974.0              M
# 2538573             TPE                 1976.0              M
# 2538574             TPE                 1969.0              F
# 2538575             TPE                 1964.0              M
#
#         Athlete age category Athlete average speed  Athlete ID
# 2538571                  M50                10.627       53107
# 2538572                  M45                10.409        8785
# 2538573                  M40                 9.962        4502
# 2538574                  W50                 9.452       63964
# 2538575                  M55                 9.379        4485

# %%
df[df['Event name'].str.split('(').str[1].str.split(')').str[0] == 'USA']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7117228           2015  09.10.2015
# 7117229           2015  09.10.2015
# 7117230           2015  09.10.2015
# 7117231           2015  09.10.2015
# 7117232           2015  09.10.2015
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...                                                ...                   ...
# 7117228              West Virginia Trilogy 50 km (USA)                  50km
# 7117229              West Virginia Trilogy 50 km (USA)                  50km
# 7117230              West Virginia Trilogy 50 km (USA)                  50km
# 7117231              West Virginia Trilogy 50 km (USA)                  50km
# 7117232              West Virginia Trilogy 50 km (USA)                  50km
#
#          Event number of finishers Athlete performance      Athlete club  \
# 55                               9           9:53:05 h  *Middleville, MI
# 56                               9          11:09:35 h     *Waterloo, ON
# 57                               9          11:33:00 h    *Kitchener, ON
# 58                               9          11:38:17 h        *Utica, MI
# 59                               9          11:56:35 h   *Grass Lake, MI
# ...                            ...                 ...               ...
# 7117228                         79           9:40:15 h    *Pennsboro, WV
# 7117229                         79           9:49:58 h       *Fenton, MI
# 7117230                         79           9:49:58 h      *Kimball, MI
# 7117231                         79           9:53:02 h   *Cumberland, MD
# 7117232                         79          10:22:10 h   *Morgantown, WV
#
#         Athlete country  Athlete year of birth Athlete gender  \
# 55                  USA                 1983.0              M
# 56                  CAN                 1977.0              F
# 57                  CAN                 1976.0              M
# 58                  USA                 1986.0              M
# 59                  USA                 1988.0              M
# ...                 ...                    ...            ...
# 7117228             USA                 1951.0              F
# 7117229             NED                 1960.0              F
# 7117230             USA                 1950.0              M
# 7117231             USA                 1977.0              F
# 7117232             USA                 1976.0              F
#
#         Athlete age category Athlete average speed  Athlete ID
# 55                       M23                 8.141          55
# 56                       W40                 7.211          56
# 57                       M40                 6.967          57
# 58                       M23                 6.914          58
# 59                       M23                 6.738          59
# ...                      ...                   ...         ...
# 7117228                  W60                  5.17      143968
# 7117229                  W50                 5.085      105382
# 7117230                  M60                 5.085      168233
# 7117231                  W35                 5.059       78431
# 7117232                  W35                 4.822      316320
#
# [1355619 rows x 13 columns]

# %%
#Combine all the filters together
df[(df['Event distance/length'].isin(['50km','50mi'])) 
   & (df['Year of event'] == 2020) 
   & (df['Event name'].str.split('(').str[1].str.split(')').str[0] == 'USA')]
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
# ...                ...         ...
# 2760957           2020  03.10.2020
# 2760958           2020  03.10.2020
# 2760959           2020  03.10.2020
# 2760960           2020  03.10.2020
# 2760961           2020  03.10.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
# ...                                                ...                   ...
# 2760957   Yankee Springs Fall Trail Run Festival (USA)                  50km
# 2760958   Yankee Springs Fall Trail Run Festival (USA)                  50km
# 2760959   Yankee Springs Fall Trail Run Festival (USA)                  50km
# 2760960   Yankee Springs Fall Trail Run Festival (USA)                  50km
# 2760961   Yankee Springs Fall Trail Run Festival (USA)                  50km
#
#          Event number of finishers Athlete performance  \
# 2539945                         20           3:17:55 h
# 2539946                         20           4:02:32 h
# 2539947                         20           4:07:57 h
# 2539948                         20           4:22:02 h
# 2539949                         20           4:27:34 h
# ...                            ...                 ...
# 2760957                         30           7:07:48 h
# 2760958                         30           7:27:22 h
# 2760959                         30           7:27:24 h
# 2760960                         30           7:38:30 h
# 2760961                         30           7:59:53 h
#
#                    Athlete club Athlete country  Athlete year of birth  \
# 2539945      *Normandy Park, WA             USA                 1991.0
# 2539946           *Gold Bar, WA             USA                 1981.0
# 2539947             *Vashon, WA             USA                 1999.0
# 2539948         *Gig Harbor, WA             USA                 1983.0
# 2539949  *Bainbridge Island, WA             USA                 1977.0
# ...                         ...             ...                    ...
# 2760957       *East Lansing, MI             USA                 1958.0
# 2760958      *Traverse City, MI             USA                 1977.0
# 2760959      *Traverse City, MI             USA                 1962.0
# 2760960              *Mason, MI             USA                 1981.0
# 2760961                     NaN             USA                 1980.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 2539945              M                  M23                15.158       71287
# 2539946              M                  M35                12.369      629508
# 2539947              M                 MU23                12.099       64838
# 2539948              M                  M35                11.449      704450
# 2539949              M                  M40                11.212      810281
# ...                ...                  ...                   ...         ...
# 2760957              F                  W60                 7.013      816361
# 2760958              F                  W40                 6.706      326469
# 2760959              F                  W55                 6.705      372174
# 2760960              F                  W35                 6.543      860349
# 2760961              M                  M35                 6.252      770097
#
# [26090 rows x 13 columns]

# %%
#Creating a new df 
df2 = df[(df['Event distance/length'].isin(['50km','50mi'])) 
   & (df['Year of event'] == 2020) 
   & (df['Event name'].str.split('(').str[1].str.split(')').str[0] == 'USA')].copy()

# %%
#Shape new df
df2.shape
# Out:
# (26090, 13)

# %%
#Remove USA from event name
df2['Event name'].str.split('(').str[0]
# Out:
# 2539945    West Seattle Beach Run - Winter Edition
# 2539946    West Seattle Beach Run - Winter Edition
# 2539947    West Seattle Beach Run - Winter Edition
# 2539948    West Seattle Beach Run - Winter Edition
# 2539949    West Seattle Beach Run - Winter Edition
#                              ...
# 2760957     Yankee Springs Fall Trail Run Festival
# 2760958     Yankee Springs Fall Trail Run Festival
# 2760959     Yankee Springs Fall Trail Run Festival
# 2760960     Yankee Springs Fall Trail Run Festival
# 2760961     Yankee Springs Fall Trail Run Festival
# Name: Event name, Length: 26090, dtype: object

# %%
df2['Event name'] = df2['Event name'].str.split('(').str[0]

# %%
#Checking results
df2.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20           3:17:55 h
# 2539946                  50km                         20           4:02:32 h
# 2539947                  50km                         20           4:07:57 h
# 2539948                  50km                         20           4:22:02 h
# 2539949                  50km                         20           4:27:34 h
#
#                    Athlete club Athlete country  Athlete year of birth  \
# 2539945      *Normandy Park, WA             USA                 1991.0
# 2539946           *Gold Bar, WA             USA                 1981.0
# 2539947             *Vashon, WA             USA                 1999.0
# 2539948         *Gig Harbor, WA             USA                 1983.0
# 2539949  *Bainbridge Island, WA             USA                 1977.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 2539945              M                  M23                15.158       71287
# 2539946              M                  M35                12.369      629508
# 2539947              M                 MU23                12.099       64838
# 2539948              M                  M35                11.449      704450
# 2539949              M                  M40                11.212      810281

# %%
#Clean up athlete age

# %%
df2['athlete_age'] = 2020 - df2['Athlete year of birth']

# %%
#Remove h from athlete performance

# %%
df2['Athlete performance'] = df2['Athlete performance'].str.split(' ').str[0]

# %%
#Checkin results
df2.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20             3:17:55
# 2539946                  50km                         20             4:02:32
# 2539947                  50km                         20             4:07:57
# 2539948                  50km                         20             4:22:02
# 2539949                  50km                         20             4:27:34
#
#                    Athlete club Athlete country  Athlete year of birth  \
# 2539945      *Normandy Park, WA             USA                 1991.0
# 2539946           *Gold Bar, WA             USA                 1981.0
# 2539947             *Vashon, WA             USA                 1999.0
# 2539948         *Gig Harbor, WA             USA                 1983.0
# 2539949  *Bainbridge Island, WA             USA                 1977.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID  \
# 2539945              M                  M23                15.158       71287
# 2539946              M                  M35                12.369      629508
# 2539947              M                 MU23                12.099       64838
# 2539948              M                  M35                11.449      704450
# 2539949              M                  M40                11.212      810281
#
#          athlete_age
# 2539945         29.0
# 2539946         39.0
# 2539947         21.0
# 2539948         37.0
# 2539949         43.0

# %%
#Drop columns: Athlete club Athlete Country, Athlete year of birth , Athlete Age Category

# %%
df2 =df2.drop(['Athlete club', 'Athlete country', 'Athlete year of birth', 'Athlete age category'],axis=1)

# %%
df2.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20             3:17:55
# 2539946                  50km                         20             4:02:32
# 2539947                  50km                         20             4:07:57
# 2539948                  50km                         20             4:22:02
# 2539949                  50km                         20             4:27:34
#
#         Athlete gender Athlete average speed  Athlete ID  athlete_age
# 2539945              M                15.158       71287         29.0
# 2539946              M                12.369      629508         39.0
# 2539947              M                12.099       64838         21.0
# 2539948              M                11.449      704450         37.0
# 2539949              M                11.212      810281         43.0

# %%
#Clean up null values

# %%
df2.isna().sum()
# Out:
# Year of event                  0
# Event dates                    0
# Event name                     0
# Event distance/length          0
# Event number of finishers      0
# Athlete performance            0
# Athlete gender                 0
# Athlete average speed          0
# Athlete ID                     0
# athlete_age                  233
# dtype: int64

# %%
df2[df2['athlete_age'].isna()]
# Out:
#          Year of event Event dates                           Event name  \
# 2547794           2020  25.01.2020        North Carolina Fat Ass 50 Km
# 2551331           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551336           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551344           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551348           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# ...                ...         ...                                  ...
# 2746543           2020  17.10.2020     Black River Trail Classic 50 Km
# 2749869           2020  17.10.2020  MuleSkinner Endurance 50 Mile Race
# 2755985           2020  10.10.2020      Man Against Horse 50 Mile Race
# 2755994           2020  10.10.2020      Man Against Horse 50 Mile Race
# 2755997           2020  10.10.2020      Man Against Horse 50 Mile Race
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2547794                  50km                         57             6:10:30
# 2551331                  50km                         54             4:46:34
# 2551336                  50km                         54             5:08:36
# 2551344                  50km                         54             5:54:04
# 2551348                  50km                         54             6:07:11
# ...                       ...                        ...                 ...
# 2746543                  50km                          8             8:31:26
# 2749869                  50mi                         27            11:55:05
# 2755985                  50mi                         23             9:03:25
# 2755994                  50mi                         23            10:37:00
# 2755997                  50mi                         23            12:30:00
#
#         Athlete gender Athlete average speed  Athlete ID  athlete_age
# 2547794              M                 8.097      811923          NaN
# 2551331              M                10.469      812656          NaN
# 2551336              M                 9.721      812657          NaN
# 2551344              F                 8.473      658221          NaN
# 2551348              M                  8.17      812660          NaN
# ...                ...                   ...         ...          ...
# 2746543              F                 5.866      857251          NaN
# 2749869              M                 6.752      857957          NaN
# 2755985              M                 8.885      859462          NaN
# 2755994              M                 7.579      398583          NaN
# 2755997              M                 6.437      859465          NaN
#
# [233 rows x 10 columns]

# %%
df2 = df.dropna()

# %%
#Check dupes

# %%
df2[df2.duplicated() == True]
# Out:
#          Year of event            Event dates  \
# 577695            2018  31.12.2018-01.01.2019
# 577697            2018  31.12.2018-01.01.2019
# 970871            2016         17.-18.08.2016
# 970872            2016         17.-18.08.2016
# 1116779           2016  28.12.2016-03.01.2017
# 1116780           2016  28.12.2016-03.01.2017
# 1116822           2016  28.12.2016-03.01.2017
# 1204313           2017             18.02.2017
# 3777483           1983         03.-04.09.1983
# 4141998           2000             16.06.2000
# 4314430           2002             16.03.2002
# 4477722           2004             10.04.2004
# 4656086           2006             16.06.2006
# 4778386           2007         21.-22.07.2007
# 4824594           2008         17.-18.05.2008
# 4824597           2008         17.-18.05.2008
# 4824598           2008         17.-18.05.2008
# 4980367           2009             24.05.2009
# 5193792           2010             29.05.2010
# 5649202           2012             07.04.2012
#
#                                     Event name Event distance/length  \
# 577695             Across the Years, 24h (USA)                   24h
# 577697             Across the Years, 24h (USA)                   24h
# 970871       Silverton 24 hour Challenge (USA)                   24h
# 970872       Silverton 24 hour Challenge (USA)                   24h
# 1116779            Across the Years, 24h (USA)                   24h
# 1116780            Across the Years, 24h (USA)                   24h
# 1116822            Across the Years, 24h (USA)                   24h
# 1204313     Black Canyon Trail 60 Km Run (USA)                  60km
# 3777483                 100 km Lauf Unna (GER)                 100km
# 4141998       Comrades Marathon - Up Run (RSA)                  87km
# 4314430                  Om Die Dam 50km (RSA)                  50km
# 4477722              Two Oceans Marathon (RSA)                  56km
# 4656086       Comrades Marathon - Up Run (RSA)                  87km
# 4778386  Vermont 100 Mile Endurance Race (USA)                 100mi
# 4824594     The North Face 100 Australia (AUS)                 100km
# 4824597     The North Face 100 Australia (AUS)                 100km
# 4824598     The North Face 100 Australia (AUS)                 100km
# 4980367     Comrades Marathon - Down Run (RSA)                  89km
# 5193792          Nanny Goat 12 Hour Race (USA)                   12h
# 5649202              Two Oceans Marathon (RSA)                  56km
#
#          Event number of finishers Athlete performance  \
# 577695                         173           50.684 km
# 577697                         173           50.684 km
# 970871                           6           49.889 km
# 970872                           6           49.889 km
# 1116779                        139           81.095 km
# 1116780                        139           81.095 km
# 1116822                        139           55.753 km
# 1204313                        110           9:21:17 h
# 3777483                        579          11:45:10 h
# 4141998                      20027          10:32:11 h
# 4314430                       2015           4:40:28 h
# 4477722                       8689           5:27:36 h
# 4656086                       9847           7:52:18 h
# 4778386                        142          27:11:08 h
# 4824594                        135          14:54:00 h
# 4824597                        135          14:58:00 h
# 4824598                        135          14:59:00 h
# 4980367                      10003          11:45:07 h
# 5193792                         50           48.280 km
# 5649202                       7700           5:44:25 h
#
#                       Athlete club Athlete country  Athlete year of birth  \
# 577695             *West Hills, CA             USA                 1958.0
# 577697             *West Hills, CA             USA                 1958.0
# 970871        *North Las Vegas, NV             USA                 1968.0
# 970872        *North Las Vegas, NV             USA                 1968.0
# 1116779                  *Mesa, AZ             USA                 1945.0
# 1116780                  *Mesa, AZ             USA                 1945.0
# 1116822       *North Las Vegas, NV             USA                 1968.0
# 1204313              *Shiprock, NM             USA                 1975.0
# 3777483                 *Frankfurt             GER                 1943.0
# 4141998     Pinetown & District AC             RSA                 1957.0
# 4314430    Alpha Centurion Runners             RSA                 1961.0
# 4477722         Legogote Villagers             RSA                 1961.0
# 4656086           Fit 2000 AC - CG             RSA                 1981.0
# 4778386            *Manchester, NH             USA                 1968.0
# 4824594                       *VIC             AUS                 1963.0
# 4824597                       *VIC             AUS                 1968.0
# 4824598                       *Qld             AUS                 1974.0
# 4980367  Germiston Callies Harr...             RSA                 1961.0
# 5193792                        *CA             USA                 1951.0
# 5649202  Anglo American Thermal...             RSA                 1979.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 577695               F                  W60                 2.112      340660
# 577697               F                  W60                 2.112      340660
# 970871               F                  W45                 2.079      375392
# 970872               F                  W45                 2.079      375392
# 1116779              F                  W70                 3.379       76091
# 1116780              F                  W70                 3.379       76091
# 1116822              F                  W45                 2.323      375392
# 1204313              F                  W40                 6.414       42964
# 3777483              M                  M40                 8.509     1093666
# 4141998              F                  W40                 8.257     1148252
# 4314430              M                  M40                10.696      378151
# 4477722              M                  M40                10.256       16051
# 4656086              M                  M23                11.052     1287074
# 4778386              M                  M35                  5.92      568609
# 4824594              M                  M40                 6.711       56605
# 4824597              M                  M40                 6.682        8805
# 4824598              F                  W23                 6.674     1249652
# 4980367              M                  M45                 7.573     1287836
# 5193792              M                  M55                 4.023     1112243
# 5649202              F                  W23                 9.756     1200370

# %%
#Drop dupes

# %%
df2 = df2.drop_duplicates()

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
#Reset index

# %%
df2.reset_index(drop=True)
# Out:
#          Year of event Event dates                         Event name  \
# 0                 2018  06.01.2018                Selva Costera (CHI)
# 1                 2018  06.01.2018                Selva Costera (CHI)
# 2                 2018  06.01.2018                Selva Costera (CHI)
# 3                 2018  06.01.2018                Selva Costera (CHI)
# 4                 2018  06.01.2018                Selva Costera (CHI)
# ...                ...         ...                                ...
# 4242472           2015  09.10.2015  West Virginia Trilogy 50 km (USA)
# 4242473           2015  09.10.2015  West Virginia Trilogy 50 km (USA)
# 4242474           2015  09.10.2015  West Virginia Trilogy 50 km (USA)
# 4242475           2015  09.10.2015  West Virginia Trilogy 50 km (USA)
# 4242476           2015  09.10.2015  West Virginia Trilogy 50 km (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 0                        50km                         22           4:51:39 h
# 1                        50km                         22           5:15:45 h
# 2                        50km                         22           5:16:44 h
# 3                        50km                         22           5:34:13 h
# 4                        50km                         22           5:54:14 h
# ...                       ...                        ...                 ...
# 4242472                  50km                         79           9:40:15 h
# 4242473                  50km                         79           9:49:58 h
# 4242474                  50km                         79           9:49:58 h
# 4242475                  50km                         79           9:53:02 h
# 4242476                  50km                         79          10:22:10 h
#
#                Athlete club Athlete country  Athlete year of birth  \
# 0                     Tnfrc             CHI                 1978.0
# 1        Roberto Echeverría             CHI                 1981.0
# 2         Puro Trail Osorno             CHI                 1987.0
# 3                  Columbia             ARG                 1976.0
# 4            Baguales Trail             CHI                 1992.0
# ...                     ...             ...                    ...
# 4242472      *Pennsboro, WV             USA                 1951.0
# 4242473         *Fenton, MI             NED                 1960.0
# 4242474        *Kimball, MI             USA                 1950.0
# 4242475     *Cumberland, MD             USA                 1977.0
# 4242476     *Morgantown, WV             USA                 1976.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 0                    M                  M35                10.286           0
# 1                    M                  M35                 9.501           1
# 2                    M                  M23                 9.472           2
# 3                    M                  M40                 8.976           3
# 4                    M                  M23                 8.469           4
# ...                ...                  ...                   ...         ...
# 4242472              F                  W60                  5.17      143968
# 4242473              F                  W50                 5.085      105382
# 4242474              M                  M60                 5.085      168233
# 4242475              F                  W35                 5.059       78431
# 4242476              F                  W35                 4.822      316320
#
# [4242477 rows x 13 columns]

# %%
#Fix types

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
df2['athlete_age'] = df2['athlete_age'].astype(int)

# %%
#Rename columns

# %%
df2 = df2.rename(columns={'Year of event':'year',
                        'Event dates':'race_day',
                        'Event name':'race_name',
                        'Event distance/length':'race_length',
                        'Event number of finishers':'race_number_of_finishers',
                        'Athlete performance':'athlete_performance',
                        'Athlete gender':'athelte_gender',
                        'Athlete average speed':'athlete_average_speed',
                        'Athlete ID':'athlete_id'
})

# %%
df2.head()
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance        Athlete club  \
# 0                         22           4:51:39 h               Tnfrc
# 1                         22           5:15:45 h  Roberto Echeverría
# 2                         22           5:16:44 h   Puro Trail Osorno
# 3                         22           5:34:13 h            Columbia
# 4                         22           5:54:14 h      Baguales Trail
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# 0             CHI                 1978.0              M                  M35
# 1             CHI                 1981.0              M                  M35
# 2             CHI                 1987.0              M                  M23
# 3             ARG                 1976.0              M                  M40
# 4             CHI                 1992.0              M                  M23
#
#   Athlete average speed  Athlete ID  athlete_age
# 0                10.286           0           42
# 1                 9.501           1           39
# 2                 9.472           2           33
# 3                 8.976           3           44
# 4                 8.469           4           28

# %%
#Re-order columns

# %%
df3 = df2[['race_day','race_name','race_length','race_number_of_finishers','athlete_id','athelte_gender','athlete_age','athlete_performance','athlete_average_speed','year']]

# %%
df3.head()
# Out:
#      race_day            race_name race_length  race_number_of_finishers  \
# 0  06.01.2018  Selva Costera (CHI)        50km                        22
# 1  06.01.2018  Selva Costera (CHI)        50km                        22
# 2  06.01.2018  Selva Costera (CHI)        50km                        22
# 3  06.01.2018  Selva Costera (CHI)        50km                        22
# 4  06.01.2018  Selva Costera (CHI)        50km                        22
#
#    athlete_id athelte_gender  athlete_age athlete_performance  \
# 0           0              M           42           4:51:39 h
# 1           1              M           39           5:15:45 h
# 2           2              M           33           5:16:44 h
# 3           3              M           44           5:34:13 h
# 4           4              M           28           5:54:14 h
#
#   athlete_average_speed  year
# 0                10.286  2018
# 1                 9.501  2018
# 2                 9.472  2018
# 3                 8.976  2018
# 4                 8.469  2018

# %%
#Find 2 races that i ran in 202 - Sarasota / Everglades

# %%
df3[df3['race_name'] == 'Everglades 50 Mile Ultra Run ']
# Out:
# Empty DataFrame
# Columns: [race_day, race_name, race_length, race_number_of_finishers, athlete_id, athelte_gender, athlete_age, athlete_performance, athlete_average_speed, year]
# Index: []

# %%
#222509

# %%
df3[df3['athlete_id'] == 222509]
# Out:
#            race_day                                     race_name race_length  \
# 327898   28.07.2018  Minnesota Voyageur Trail 50 Mile Ultra (USA)        50mi
# 2591482  14.03.2020            Everglades 50 Mile Ultra Run (USA)        50mi
#
#          race_number_of_finishers  athlete_id athelte_gender  athlete_age  \
# 327898                        346      222509              M           23
# 2591482                        40      222509              M           23
#
#         athlete_performance athlete_average_speed  year
# 327898           13:35:57 h                 5.917  2018
# 2591482           9:19:10 h                 8.634  2020

# %%
#Con query
df3.query('athlete_id == 222509')
# Out:
#            race_day                                     race_name race_length  \
# 327898   28.07.2018  Minnesota Voyageur Trail 50 Mile Ultra (USA)        50mi
# 2591482  14.03.2020            Everglades 50 Mile Ultra Run (USA)        50mi
#
#          race_number_of_finishers  athlete_id athelte_gender  athlete_age  \
# 327898                        346      222509              M           23
# 2591482                        40      222509              M           23
#
#         athlete_performance athlete_average_speed  year
# 327898           13:35:57 h                 5.917  2018
# 2591482           9:19:10 h                 8.634  2020

# %%
#Charts and graphs

# %%
sns.histplot(df3['race_length'])
# Out:
# <Axes: xlabel='race_length', ylabel='Count'>

# %%
#Correción de columna

# %%
df3 = df3.rename(columns={'athelte_gender':'athlete_gender'})

# %%
sns.histplot(df3, x='race_length', hue='athlete_gender')
# Out:
# <Axes: xlabel='race_length', ylabel='Count'>

# %%
sns.distplot(df3[df3['race_length'] == '50mi']['athlete_average_speed'])
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_15804\1143281526.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df3[df3['race_length'] == '50mi']['athlete_average_speed'])
# <Axes: xlabel='athlete_average_speed', ylabel='Density'>

# %%
#Difference in speed for the 50km,50mi male to female

# %%
#df3.groupby(['race_length','athlete_gender'])['athlete_average_speed'].mean()

# %%
#What age groups are the best in the 50mi Race(20 + race min)

# %%
#df3.query('race_length == "50mi"').groupby('athlete_age')['athlete_average_speed'].agg(['mean','count']).sort_values('mean', ascending=False).query('count>19')

# %%
#Season for the data
#spring 3-5
#summer 6-8
#fall 9-11
#winter 12-2

# %%
df3['race_month'] = df3['race_day'].str.split('.').str[1].astype(int)

# %%
df3['race_season'] = df3['race_month'].apply(lambda x: 'Winter' if x>11 else 'Fall' if x>8 else 'Summer' if x>5 else 'Spring' if x>2 else 'Winter')

# %%
df3
# Out:
#            race_day                          race_name race_length  \
# 0        06.01.2018                Selva Costera (CHI)        50km
# 1        06.01.2018                Selva Costera (CHI)        50km
# 2        06.01.2018                Selva Costera (CHI)        50km
# 3        06.01.2018                Selva Costera (CHI)        50km
# 4        06.01.2018                Selva Costera (CHI)        50km
# ...             ...                                ...         ...
# 7117228  09.10.2015  West Virginia Trilogy 50 km (USA)        50km
# 7117229  09.10.2015  West Virginia Trilogy 50 km (USA)        50km
# 7117230  09.10.2015  West Virginia Trilogy 50 km (USA)        50km
# 7117231  09.10.2015  West Virginia Trilogy 50 km (USA)        50km
# 7117232  09.10.2015  West Virginia Trilogy 50 km (USA)        50km
#
#          race_number_of_finishers  athlete_id athlete_gender  athlete_age  \
# 0                              22           0              M           42
# 1                              22           1              M           39
# 2                              22           2              M           33
# 3                              22           3              M           44
# 4                              22           4              M           28
# ...                           ...         ...            ...          ...
# 7117228                        79      143968              F           69
# 7117229                        79      105382              F           60
# 7117230                        79      168233              M           70
# 7117231                        79       78431              F           43
# 7117232                        79      316320              F           44
#
#         athlete_performance athlete_average_speed  year  race_month  \
# 0                 4:51:39 h                10.286  2018           1
# 1                 5:15:45 h                 9.501  2018           1
# 2                 5:16:44 h                 9.472  2018           1
# 3                 5:34:13 h                 8.976  2018           1
# 4                 5:54:14 h                 8.469  2018           1
# ...                     ...                   ...   ...         ...
# 7117228           9:40:15 h                  5.17  2015          10
# 7117229           9:49:58 h                 5.085  2015          10
# 7117230           9:49:58 h                 5.085  2015          10
# 7117231           9:53:02 h                 5.059  2015          10
# 7117232          10:22:10 h                 4.822  2015          10
#
#         race_season
# 0            Winter
# 1            Winter
# 2            Winter
# 3            Winter
# 4            Winter
# ...             ...
# 7117228        Fall
# 7117229        Fall
# 7117230        Fall
# 7117231        Fall
# 7117232        Fall
#
# [4242497 rows x 12 columns]

# %%
#df3.groupby('race_season')['athlete_average_speed'].agg(['mean','count']).sort_values('mean', ascending=False)
